# %%
import pandas as pd
songs = pd.read_csv('../data/song_recommender.csv')

# %%
songs
# Out:
#                    Artist                                              Title  \
# 0           Morgan Wallen                                         Last Night
# 1              Luke Combs                                           Fast Car
# 2          Olivia Rodrigo                                            Vampire
# 3     Rema & Selena Gomez                                          Calm Down
# 4            Taylor Swift  I Can See You (Taylor's Version) (From The Vault)
# ...                   ...                                                ...
# 5054            2 Chainz                                       2 Dollar Bill
# 5055  Christina Aguilera                                   Genie in a Bottle
# 5056      Joshua Bassett                                              Crisis
# 5057               Nelly                          Country Grammar (Hot Shit)
# 5058                 JID                                           Westbrook
#
# ...

# %%
df = songs
import pandas as pd

# Assuming 'df' is your DataFrame
# Check if 'id' column contains the value '5u2vOSftv32iQpSZvP6ugV'
value_to_find = '5u2vOSftv32iQpSZvP6ugV'
is_value_present = value_to_find in df['id'].values

# Find row index(es) where the value exists
if is_value_present:
    row_indices = df.index[df['id'] == value_to_find].tolist()
    print(f"The value '{value_to_find}' is present in the 'id' column.")
    print(f"The row index(es) where the value is present: {row_indices}")
else:
    print(f"The value '{value_to_find}' is not present in the 'id' column.")
# Out:
# The value '5u2vOSftv32iQpSZvP6ugV' is present in the 'id' column.
# The row index(es) where the value is present: [813]

# %%
df.iloc[813,:]
# Out:
# Artist                                                 One Direction
# Title                                                          Clouds
# id                                             5u2vOSftv32iQpSZvP6ugV
# danceability                                                    0.404
# energy                                                          0.333
# key                                                                11
# loudness                                                      -16.516
# mode                                                                1
# speechiness                                                    0.0364
# acousticness                                                    0.873
# instrumentalness                                                0.877
# liveness                                                        0.381
# valence                                                         0.131
# ...
