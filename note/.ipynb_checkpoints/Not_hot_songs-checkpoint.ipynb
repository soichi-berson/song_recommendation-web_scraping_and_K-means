# %% [markdown]
# # Lab_Not_hot_songs

# %%
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
import requests

# %%
nothot100 = pd.read_csv("../data/Spotify_final_dataset.csv")

# %%
nothot100.head()
# Out:
#    Position    Artist Name                                   Song Name  Days  \
# 0         1   Post Malone   Sunflower  SpiderMan: Into the SpiderVerse  1506
# 1         2    Juice WRLD                                 Lucid Dreams  1673
# 2         3  Lil Uzi Vert                                XO TOUR Llif3  1853
# 3         4       J. Cole                               No Role Modelz  2547
# 4         5   Post Malone                                     rockstar  1223
#
#    Top 10 (xTimes)  Peak Position Peak Position (xTimes)  Peak Streams  \
# 0            302.0              1                  (x29)       2118242
# 1            178.0              1                  (x20)       2127668
# 2            212.0              1                   (x4)       1660502
# 3              6.0              7                      0        659366
# 4            186.0              1                 (x124)       2905678
#
#    Total Streams
# 0      883369738
# 1      864832399
# 2      781153024
# 3      734857487
# 4      718865961

# %%
nothot100.sample(5000)
# Out:
#        Position            Artist Name                            Song Name  \
# 3647       3648             DJ Khaled                             BEAUTIFUL
# 9578       9579               Takeoff                           Infatuation
# 3973       3974            Kanye West                       Tell The Vision
# 5166       5167          Brent Faiyaz         ADDICTIONS (FEAT. Tre' Amani)
# 10124     10125                Hozier                              Movement
# ...         ...                    ...                                  ...
# 1010       1011       Imagine Dragons                                 Enemy
# 1098       1099                *NSYNC       Merry Christmas, Happy Holidays
# 8262       8263  A Tribe Called Quest                                Mobius
# 5297       5298        Run The Jewels                                  JU$T
# 3220       3221          Shawn Mendes   Like To Be You feat. Julia Michaels
#
#        Days  Top 10 (xTimes)  Peak Position Peak Position (xTimes)  \
# 3647     14              0.0             13                      0
# 9578      1              0.0            165                      0
# 3973      8              0.0             23                      0
# 5166      6              0.0             33                      0
# 10124     1              0.0            200                      0
# ...     ...              ...            ...                    ...
# 1010     95             16.0              8                      0
# 1098    125              0.0             30                      0
# 8262      3              0.0            172                      0
# 5297      7              0.0             41                      0
# 3220     32              0.0             78                      0
#
#        Peak Streams  Total Streams
# 3647         788486        5625094
# 9578         255665         255665
# 3973        1071215        4357258
# 5166         554821        2076297
# 10124        226276         226276
# ...             ...            ...
# 1010         665972       50995955
# 1098        1521093       45744894
# 8262         137356         396617
# 5297         455072        1941263
# 3220         463987        7758886
#
# [5000 rows x 9 columns]

# %%
nothot100 = nothot100[["Artist Name","Song Name"]]
nothot100.head()
# Out:
#      Artist Name                                   Song Name
# 0   Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1    Juice WRLD                                 Lucid Dreams
# 2  Lil Uzi Vert                                XO TOUR Llif3
# 3       J. Cole                               No Role Modelz
# 4   Post Malone                                     rockstar

# %%
nothot100 = nothot100.rename(columns={'Artist Name': 'Artist', 'Song Name': 'Title'})
nothot100.head()
# Out:
#           Artist                                       Title
# 0   Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1    Juice WRLD                                 Lucid Dreams
# 2  Lil Uzi Vert                                XO TOUR Llif3
# 3       J. Cole                               No Role Modelz
# 4   Post Malone                                     rockstar

# %%
nothot100.to_csv('../data/nothot100.csv', index=False)
